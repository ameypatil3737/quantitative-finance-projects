# %%
5 VaR using historical simulation

# %%
import numpy as np
import pandas as pd

def calculate_var(prices, confidence_level=0.95):
    returns = prices.pct_change().dropna()
    sorted_returns = np.sort(returns)
    index = int((1 - confidence_level) * len(sorted_returns))
    print("len(sorted_returns):",len(sorted_returns)) #{len(sorted_returns)}")
    var = abs(sorted_returns[index])
    return var

# Load data
data = pd.read_csv('./historical_stock_prices.csv', index_col='Date', parse_dates=True)
prices = data['Close']

# Calculate VaR
var_95 = calculate_var(prices, 0.95)
print(f"95% VaR: {var_95}")
# Out:
# len(sorted_returns): 250
# 95% VaR: 0.01999219221564008

# %%
import numpy as np
import pandas as pd

def calculate_var(prices, confidence_level=0.95):
    returns = prices.pct_change().dropna()
    print("returns")
    print(returns)
    sorted_returns = np.sort(returns)
    print("sorted_returns")
    print(sorted_returns)
    index = int((1 - confidence_level) * len(sorted_returns))
    print("Index")
    print(index)
    print("len(sorted_returns):",len(sorted_returns)) #{len(sorted_returns)}")
    var = abs(sorted_returns[index])
    print("Var")
    print(var)
    return var

# Load data
data = pd.read_csv('./historical_stock_prices.csv', index_col='Date', parse_dates=True)
prices = data['Close']

# Calculate VaR
var_95 = calculate_var(prices, 0.95)
print(f"95% VaR: {var_95}")
# Out:
# returns
# Date
# 2023-06-13   -0.002612
# 2023-06-14    0.003491
# 2023-06-15    0.011199
# 2023-06-16   -0.005860
# 2023-06-20    0.000487
#                 ...
# 2024-06-04    0.001649
# 2024-06-05    0.007821
# 2024-06-06   -0.007097
# 2024-06-07    0.012392
# 2024-06-10   -0.019148
# Name: Close, Length: 250, dtype: float64
# sorted_returns
# [-4.80200507e-02 -4.08574639e-02 -3.57933216e-02 -3.57866308e-02
#  -2.92493898e-02 -2.84409528e-02 -2.61704402e-02 -2.53812640e-02
#  -2.46055339e-02 -2.33984266e-02 -2.18635001e-02 -2.10580887e-02
#  -1.99921922e-02 -1.93575789e-02 -1.92458305e-02 -1.91672764e-02
#  -1.91477679e-02 -1.82708818e-02 -1.72536893e-02 -1.70606489e-02
#  -1.54900004e-02 -1.47042169e-02 -1.45551730e-02 -1.34916742e-02
#  -1.29273615e-02 -1.27001140e-02 -1.23170881e-02 -1.22126023e-02
#  -1.21225599e-02 -1.18547701e-02 -1.12743845e-02 -1.12003228e-02
#  -1.11392646e-02 -1.08558426e-02 -1.07139229e-02 -1.05591254e-02
#  -1.02927394e-02 -1.00973908e-02 -1.00341219e-02 -9.46460967e-03
#  -9.10676167e-03 -9.01272090e-03 -9.00191658e-03 -8.95439918e-03
#  -8.89749906e-03 -8.88946353e-03 -8.78473026e-03 -8.58364298e-03
#  -8.50335547e-03 -8.45577930e-03 -8.43034369e-03 -8.30040056e-03
#  -8.23537922e-03 -8.14739024e-03 -7.78467800e-03 -7.76981871e-03
#  -7.55297329e-03 -7.53840372e-03 -7.48760508e-03 -7.45123806e-03
#  -7.39485207e-03 -7.32165326e-03 -7.09653870e-03 -7.00432290e-03
#  -6.99878261e-03 -6.67251367e-03 -6.66355105e-03 -6.62545566e-03
#  -6.58097172e-03 -6.16166815e-03 -6.04707913e-03 -6.03040664e-03
#  -5.89127267e-03 -5.87820379e-03 -5.87137566e-03 -5.85988403e-03
#  -5.75469604e-03 -5.71432738e-03 -5.68705931e-03 -5.67530419e-03
#  -5.54749866e-03 -5.42412950e-03 -5.40965878e-03 -5.40508934e-03
